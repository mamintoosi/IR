# %%
import nltk
from nltk.corpus import movie_reviews
from nltk.classify import NaiveBayesClassifier
import nltk.classify.util as util
from nltk.collocations import BigramCollocationFinder as BCF
from nltk.metrics import BigramAssocMeasures
import itertools

# %%
def features(words):
	scoreF = BigramAssocMeasures.chi_sq

	#bigram count
	n = 430

	bigrams = BCF.from_words(words).nbest(scoreF, n)

	return dict([word,True] for word in itertools.chain(words, bigrams))

# %%
pid = movie_reviews.fileids('neg')
nid = movie_reviews.fileids('pos')

prev = [(features(movie_reviews.words(fileids = id)), 'positive') for id in pid]
nrev = [(features(movie_reviews.words(fileids = id)), 'negative') for id in nid]

ncutoff = int(len(nrev)*3/4)
pcutoff = int(len(prev)*3/4)

train_set = nrev[:ncutoff] + prev[:pcutoff]
test_set = nrev[ncutoff:] + prev[pcutoff:]


# NaiveBayesClassifier
classifier = NaiveBayesClassifier.train(train_set)

# Accuracy
print ("Accuracy is : ", util.accuracy(classifier, test_set) * 100)
# Out:
# Accuracy is :  85.0

# %%
prev[0]
# Out:
# ({'plot': True,
#   ':': True,
#   'two': True,
#   'teen': True,
#   'couples': True,
#   'go': True,
#   'to': True,
#   'a': True,
#   'church': True,
#   'party': True,
#   ',': True,
#   'drink': True,
#   'and': True,
#   'then': True,
#   'drive': True,
#   '.': True,
#   'they': True,
#   'get': True,
#   'into': True,
#   'an': True,
#   'accident': True,
#   'one': True,
#   'of': True,
#   'the': True,
#   'guys': True,
#   'dies': True,
#   'but': True,
#   'his': True,
#   'girlfriend': True,
#   'continues': True,
#   'see': True,
#   'him': True,
#   'in': True,
#   'her': True,
#   'life': True,
#   'has': True,
#   'nightmares': True,
#   'what': True,
#   "'": True,
#   's': True,
#   'deal': True,
#   '?': True,
#   'watch': True,
#   'movie': True,
#   '"': True,
#   'sorta': True,
#   'find': True,
#   'out': True,
#   'critique': True,
#   'mind': True,
#   '-': True,
#   'fuck': True,
#   'for': True,
#   'generation': True,
#   'that': True,
#   'touches': True,
#   'on': True,
#   'very': True,
#   'cool': True,
#   'idea': True,
#   'presents': True,
#   'it': True,
#   'bad': True,
#   'package': True,
#   'which': True,
#   'is': True,
#   'makes': True,
#   'this': True,
#   'review': True,
#   'even': True,
#   'harder': True,
#   'write': True,
#   'since': True,
#   'i': True,
#   'generally': True,
#   'applaud': True,
#   'films': True,
#   'attempt': True,
#   'break': True,
#   'mold': True,
#   'mess': True,
#   'with': True,
#   'your': True,
#   'head': True,
#   'such': True,
#   '(': True,
#   'lost': True,
#   'highway': True,
#   '&': True,
#   'memento': True,
#   ')': True,
#   'there': True,
#   'are': True,
#   'good': True,
#   'ways': True,
#   'making': True,
#   'all': True,
#   'types': True,
#   'these': True,
#   'folks': True,
#   'just': True,
#   'didn': True,
#   't': True,
#   'snag': True,
#   'correctly': True,
#   'seem': True,
#   'have': True,
#   'taken': True,
#   'pretty': True,
#   'neat': True,
#   'concept': True,
#   'executed': True,
#   'terribly': True,
#   'so': True,
#   'problems': True,
#   'well': True,
#   'its': True,
#   'main': True,
#   'problem': True,
#   'simply': True,
#   'too': True,
#   'jumbled': True,
#   'starts': True,
#   'off': True,
#   'normal': True,
#   'downshifts': True,
#   'fantasy': True,
#   'world': True,
#   'you': True,
#   'as': True,
#   'audience': True,
#   'member': True,
#   'no': True,
#   'going': True,
#   'dreams': True,
#   'characters': True,
#   'coming': True,
#   'back': True,
#   'from': True,
#   'dead': True,
#   'others': True,
#   'who': True,
#   'look': True,
#   'like': True,
#   'strange': True,
#   'apparitions': True,
#   'disappearances': True,
#   'looooot': True,
#   'chase': True,
#   'scenes': True,
#   'tons': True,
#   'weird': True,
#   'things': True,
#   'happen': True,
#   'most': True,
#   'not': True,
#   'explained': True,
#   'now': True,
#   'personally': True,
#   'don': True,
#   'trying': True,
#   'unravel': True,
#   'film': True,
#   'every': True,
#   'when': True,
#   'does': True,
#   'give': True,
#   'me': True,
#   'same': True,
#   'clue': True,
#   'over': True,
#   'again': True,
#   'kind': True,
#   'fed': True,
#   'up': True,
#   'after': True,
#   'while': True,
#   'biggest': True,
#   'obviously': True,
#   'got': True,
#   'big': True,
#   'secret': True,
#   'hide': True,
#   'seems': True,
#   'want': True,
#   'completely': True,
#   'until': True,
#   'final': True,
#   'five': True,
#   'minutes': True,
#   'do': True,
#   'make': True,
#   'entertaining': True,
#   'thrilling': True,
#   'or': True,
#   'engaging': True,
#   'meantime': True,
#   'really': True,
#   'sad': True,
#   'part': True,
#   'arrow': True,
#   'both': True,
#   'dig': True,
#   'flicks': True,
#   'we': True,
#   'actually': True,
#   'figured': True,
#   'by': True,
#   'half': True,
#   'way': True,
#   'point': True,
#   'strangeness': True,
#   'did': True,
#   'start': True,
#   'little': True,
#   'bit': True,
#   'sense': True,
#   'still': True,
#   'more': True,
#   'guess': True,
#   'bottom': True,
#   'line': True,
#   'movies': True,
#   'should': True,
#   'always': True,
#   'sure': True,
#   'before': True,
#   'given': True,
#   'password': True,
#   'enter': True,
#   'understanding': True,
#   'mean': True,
#   'showing': True,
#   'melissa': True,
#   'sagemiller': True,
#   'running': True,
#   'away': True,
#   'visions': True,
#   'about': True,
#   '20': True,
#   'throughout': True,
#   'plain': True,
#   'lazy': True,
#   '!': True,
#   'okay': True,
#   'people': True,
#   'chasing': True,
#   'know': True,
#   'need': True,
#   'how': True,
#   'giving': True,
#   'us': True,
#   'different': True,
#   'offering': True,
#   'further': True,
#   'insight': True,
#   'down': True,
#   'apparently': True,
#   'studio': True,
#   'took': True,
#   'director': True,
#   'chopped': True,
#   'themselves': True,
#   'shows': True,
#   'might': True,
#   've': True,
#   'been': True,
#   'decent': True,
#   'here': True,
#   'somewhere': True,
#   'suits': True,
#   'decided': True,
#   'turning': True,
#   'music': True,
#   'video': True,
#   'edge': True,
#   'would': True,
#   'actors': True,
#   'although': True,
#   'wes': True,
#   'bentley': True,
#   'seemed': True,
#   'be': True,
#   'playing': True,
#   'exact': True,
#   'character': True,
#   'he': True,
#   'american': True,
#   'beauty': True,
#   'only': True,
#   'new': True,
#   'neighborhood': True,
#   'my': True,
#   'kudos': True,
#   'holds': True,
#   'own': True,
#   'entire': True,
#   'feeling': True,
#   'unraveling': True,
#   'overall': True,
#   'doesn': True,
#   'stick': True,
#   'because': True,
#   'entertain': True,
#   'confusing': True,
#   'rarely': True,
#   'excites': True,
#   'feels': True,
#   'redundant': True,
#   'runtime': True,
#   'despite': True,
#   'ending': True,
#   'explanation': True,
#   'craziness': True,
#   'came': True,
#   'oh': True,
#   'horror': True,
#   'slasher': True,
#   'flick': True,
#   'packaged': True,
#   'someone': True,
#   'assuming': True,
#   'genre': True,
#   'hot': True,
#   'kids': True,
#   'also': True,
#   'wrapped': True,
#   'production': True,
#   'years': True,
#   'ago': True,
#   'sitting': True,
#   'shelves': True,
#   'ever': True,
#   'whatever': True,
#   'skip': True,
#   'where': True,
#   'joblo': True,
#   'nightmare': True,
#   'elm': True,
#   'street': True,
#   '3': True,
#   '7': True,
#   '/': True,
#   '10': True,
#   'blair': True,
#   'witch': True,
#   '2': True,
#   'crow': True,
#   '9': True,
#   'salvation': True,
#   '4': True,
#   'stir': True,
#   'echoes': True,
#   '8': True,
#   ('also', 'wrapped'): True,
#   ('although', 'wes'): True,
#   ('american', 'beauty'): True,
#   ('be', 'playing'): True,
#   ('blair', 'witch'): True,
#   ('both', 'dig'): True,
#   ('bottom', 'line'): True,
#   ('church', 'party'): True,
#   ('completely', 'until'): True,
#   ('elm', 'street'): True,
#   ('final', 'five'): True,
#   ('further', 'insight'): True,
#   ('generally', 'applaud'): True,
#   ('girlfriend', 'continues'): True,
#   ('give', 'me'): True,
#   ('giving', 'us'): True,
#   ('guys', 'dies'): True,
#   ('here', 'somewhere'): True,
#   ('his', 'girlfriend'): True,
#   ('lost', 'highway'): True,
#   ('music', 'video'): True,
#   ('neat', 'concept'): True,
#   ('new', 'neighborhood'): True,
#   ('obviously', 'got'): True,
#   ('offering', 'further'): True,
#   ('people', 'chasing'): True,
#   ('plain', 'lazy'): True,
#   ('rarely', 'excites'): True,
#   ('shelves', 'ever'): True,
#   ('should', 'always'): True,
#   ('showing', 'melissa'): True,
#   ('slasher', 'flick'): True,
#   ('starts', 'off'): True,
#   ('strange', 'apparitions'): True,
#   ('street', '3'): True,
#   ('studio', 'took'): True,
#   ('these', 'folks'): True,
#   ('too', 'jumbled'): True,
#   ('us', 'different'): True,
#   ('wes', 'bentley'): True,
#   ('witch', '2'): True,
#   ('wrapped', 'production'): True,
#   ('years', 'ago'): True,
#   ('/', '10'): True,
#   ('10', ')'): True,
#   ('there', 'are'): True,
#   ("'", 's'): True,
#   (')', '-'): True,
#   ('&', 'memento'): True,
#   ('20', 'minutes'): True,
#   ('about', '20'): True,
#   ('about', 'giving'): True,
#   ('actually', 'figured'): True,
#   ('apparently', 'assuming'): True,
#   ('applaud', 'films'): True,
#   ('audience', 'member'): True,
#   ('bad', 'package'): True,
#   ('bad', 'ways'): True,
#   ('because', 'someone'): True,
#   ('been', 'sitting'): True,
#   ('big', 'secret'): True,
#   ('biggest', 'kudos'): True,
#   ('came', 'before'): True,
#   ('characters', 'coming'): True,
#   ('chase', 'scenes'): True,
#   ('coming', 'back'): True,
#   ('cool', 'ending'): True,
#   ('couples', 'go'): True,
#   ('did', 'start'): True,
#   ('different', 'scenes'): True,
#   ('enter', 'your'): True,
#   ('ever', 'since'): True,
#   ('every', 'now'): True,
#   ('exact', 'same'): True,
#   ('fed', 'up'): True,
#   ('five', 'minutes'): True,
#   ('going', 'down'): True,
#   ('have', 'no'): True,
#   ('have', 'taken'): True,
#   ('he', 'did'): True,
#   ('highway', '&'): True,
#   ('horror', 'or'): True,
#   ('how', 'about'): True,
#   ('joblo', 'coming'): True,
#   ('kudos', 'go'): True,
#   ('little', 'bit'): True,
#   ('little', 'edge'): True,
#   ('main', 'problem'): True,
#   ('melissa', 'sagemiller'): True,
#   ('my', 'biggest'): True,
#   ('no', 'idea'): True,
#   ('own', 'throughout'): True,
#   ('personally', 'don'): True,
#   ('production', 'two'): True,
#   ('really', 'need'): True,
#   ('running', 'away'): True,
#   ('sad', 'part'): True,
#   ('sagemiller', 'running'): True,
#   ('same', 'clue'): True,
#   ('scenes', 'offering'): True,
#   ('secret', 'password'): True,
#   ('see', 'him'): True,
#   ('simply', 'too'): True,
#   ('stick', 'because'): True,
#   ('still', 'hot'): True,
#   ('thrilling', 'or'): True,
#   ('two', 'years'): True,
#   ('up', 'themselves'): True,
#   ('ve', 'been'): True,
#   ('weird', 'things'): True,
#   ('your', 'head'): True,
#   ('away', 'from'): True,
#   ('over', 'again'): True,
#   ("'", 't'): True,
#   ('!', 'okay'): True,
#   ('!', 'where'): True,
#   (':', 'salvation'): True,
#   ('an', 'accident'): True,
#   ('as', 'an'): True,
#   ('critique', ':'): True,
#   ('even', 'engaging'): True,
#   ('even', 'harder'): True,
#   ('find', 'out'): True,
#   ('flicks', 'like'): True,
#   ('get', 'kind'): True,
#   ('harder', 'one'): True,
#   ('has', 'nightmares'): True,
#   ('know', 'who'): True,
#   ('lazy', '!'): True,
#   ('mind', 'trying'): True,
#   ('movies', 'like'): True,
#   ('not', 'explained'): True,
#   ('one', 'correctly'): True,
#   ('plot', ':'): True,
#   ('review', 'an'): True,
#   ('then', 'downshifts'): True,
#   ('then', 'drive'): True,
#   ('way', 'point'): True,
#   ('who', 'holds'): True,
#   ('you', 'feeling'): True,
#   ('you', 'should'): True,
#   ('fuck', 'movie'): True,
#   ('i', 'guess'): True,
#   ('back', 'from'): True,
#   ('bentley', 'just'): True,
#   ('chasing', 'her'): True,
#   ('clue', 'over'): True,
#   ('decent', 'teen'): True,
#   ('dig', 'on'): True,
#   ('feeling', 'her'): True,
#   ('figured', 'most'): True,
#   ('folks', 'just'): True,
#   ('from', 'visions'): True,
#   ('her', 'life'): True,
#   ('her', 'own'): True,
#   ('holds', 'her'): True,
#   ('its', 'director'): True,
#   ('its', 'final'): True,
#   ('its', 'main'): True,
#   ('its', 'runtime'): True,
#   ('just', 'packaged'): True,
#   ('just', 'plain'): True,
#   ('just', 'seemed'): True,
#   ('on', 'flicks'): True,
#   ('redundant', 'for'): True,
#   ('sitting', 'on'): True,
#   ('teen', 'couples'): True,
#   ('teen', 'generation'): True,
#   ('teen', 'slasher'): True,
#   ('touches', 'on'): True,
#   ('until', 'its'): True,
#   ('visions', 'for'): True,
#   ('what', 'makes'): True,
#   ('which', 'attempt'): True,
#   ('biggest', 'problem'): True,
#   ('cool', 'idea'): True,
#   ('minutes', 'throughout'): True,
#   ('more', 'entertaining'): True,
#   ('more', 'sense'): True,
#   ('same', 'character'): True,
#   ('still', 'didn'): True,
#   ('strangeness', 'after'): True,
#   ('strangeness', 'going'): True,
#   ('things', 'entertaining'): True,
#   ('up', 'after'): True,
#   ('very', 'bad'): True,
#   ('very', 'cool'): True,
#   ('your', 'world'): True,
#   ('7', '/'): True,
#   ('9', '/'): True,
#   ('(', '7'): True,
#   ('(', '9'): True,
#   ('always', 'make'): True,
#   ('downshifts', 'into'): True,
#   ('feels', 'pretty'): True,
#   ('hot', 'with'): True,
#   ('insight', 'into'): True,
#   ('line', 'with'): True,
#   ('make', 'sure'): True,
#   ('mess', 'with'): True,
#   ('pretty', 'decent'): True,
#   ('pretty', 'neat'): True,
#   ('pretty', 'redundant'): True,
#   ('problems', 'with'): True,
#   ('they', 'seem'): True,
#   ('video', 'with'): True,
#   ('with', 'movies'): True,
#   ('would', 'make'): True,
#   ('-', 'fuck'): True,
#   ('?', 'how'): True,
#   ('?', 'watch'): True,
#   ('?', 'well'): True,
#   ('all', 'types'): True,
#   ('deal', '?'): True,
#   ('entire', 'film'): True,
#   ('film', 'every'): True,
#   ('making', 'all'): True,
#   ('meantime', '?'): True,
#   ('t', 'entertain'): True,
#   ('t', 'know'): True,
#   ('t', 'snag'): True,
#   ('t', 'stick'): True,
#   ('when', 'all'): True,
#   (':', 'two'): True,
#   ('actually', 'has'): True,
#   ('an', 'audience'): True,
#   ('crow', ':'): True,
#   ('even', 'before'): True,
#   ('go', 'out'): True,
#   ('has', 'been'): True,
#   ('look', 'like'): True,
#   ('not', 'really'): True,
#   ('or', 'even'): True,
#   ('others', 'who'): True,
#   ('out', 'by'): True,
#   ('simply', 'not'): True,
#   ('way', 'because'): True,
#   ('who', 'look'): True,
#   ('i', 'both'): True,
#   ('i', 'generally'): True,
#   ('i', 'mean'): True,
#   ('i', 'personally'): True,
#   ('a', 'very'): True,
#   ('most', 'of'): True,
#   (',', 'but'): True,
#   ('like', 'this'): True,
#   ('mind', '-'): True,
#   ('4', '/'): True,
#   ('8', '/'): True,
#   ('down', 'in'): True,
#   ('him', 'in'): True,
#   ('in', 'american'): True,
#   ('in', 'here'): True,
#   ('only', 'in'): True,
#   ('coming', 'from'): True,
#   ('do', 'we'): True,
#   ('films', 'which'): True,
#   ('for', 'about'): True,
#   ('going', 'on'): True,
#   ('good', 'for'): True,
#   ('her', 'character'): True,
#   ('idea', 'what'): True,
#   ('just', 'didn'): True,
#   ('most', 'part'): True,
#   ('or', 'teen'): True,
#   ('two', 'teen'): True,
#   ('we', 'actually'): True,
#   ('we', 'don'): True,
#   ('we', 'really'): True,
#   ('didn', "'"): True,
#   ('doesn', "'"): True,
#   ('don', "'"): True,
#   ('to', 'hide'): True,
#   ('to', 'see'): True,
#   ('(', '4'): True,
#   ('(', '8'): True,
#   ('2', '('): True,
#   ('3', '('): True,
#   ('echoes', '('): True,
#   ('s', 'confusing'): True,
#   ('s', 'joblo'): True,
#   ('s', 'obviously'): True,
#   ('s', 'unraveling'): True,
#   ('salvation', '('): True,
#   ('such', '('): True,
#   ('!', '!'): True,
#   ('an', 'even'): True,
#   ('has', 'you'): True,
#   ('movie', '?'): True,
#   ('"', 'decided'): True,
#   ('"', 'fantasy'): True,
#   ('"', 'find'): True,
#   ('"', 'normal'): True,
#   ('"', 'sorta'): True,
#   ('-', 'blair'): True,
#   ('-', 'stir'): True,
#   ('but', 'executed'): True,
#   ('but', 'his'): True,
#   ('but', 'my'): True,
#   ('but', 'presents'): True,
#   ('but', 'when'): True,
#   ('fantasy', '"'): True,
#   ('got', 'this'): True,
#   ('half', '-'): True,
#   ('makes', 'this'): True,
#   ('normal', '"'): True,
#   ('off', '"'): True,
#   ('snag', 'this'): True,
#   ('sorta', '"'): True,
#   ('suits', '"'): True,
#   ('taken', 'this'): True,
#   ('there', 'might'): True,
#   ('this', 'big'): True,
#   ('this', 'review'): True,
#   ('took', 'this'): True,
#   ('before', 'they'): True,
#   ('do', 'they'): True,
#   ('make', 'more'): True,
#   ('make', 'things'): True,
#   ('pretty', 'cool'): True,
#   ('pretty', 'good'): True,
#   ('with', 'little'): True,
#   ('with', 'your'): True,
#   ('all', 'of'): True,
#   ('does', 'is'): True,
#   ('genre', 'is'): True,
#   ('is', 'give'): True,
#   ('someone', 'is'): True,
#   ('?', 'apparently'): True,
#   ('again', '?'): True,
#   ('film', 'away'): True,
#   ('film', 'doesn'): True,
#   ('so', 'we'): True,
#   ('so', 'what'): True,
#   ('teen', 'mind'): True,
#   ('we', 'get'): True,
#   ('which', 'you'): True,
#   ('which', 'is'): True,
#   ('actors', 'are'): True,
#   ('are', 'characters'): True,
#   ('are', 'disappearances'): True,
#   ('are', 'dreams'): True,
#   ('are', 'given'): True,
#   ('are', 'people'): True,
#   ('are', 'strange'): True,
#   ('are', 'tons'): True,
#   ('assuming', 'that'): True,
#   ('craziness', 'that'): True,
#   ('decided', 'that'): True,
#   ('generation', 'that'): True,
#   ('sure', 'that'): True,
#   ('that', 'came'): True,
#   ('that', 'happen'): True,
#   ('that', 'he'): True,
#   ('that', 'touches'): True,
#   ('that', 'turning'): True,
#   (',', 'there'): True,
#   ('a', 'church'): True,
#   ('a', 'horror'): True,
#   ('a', 'looooot'): True,
#   ('a', 'music'): True,
#   ('a', 'new'): True,
#   ('a', 'nightmare'): True,
#   ('a', 'while'): True,
#   ('despite', 'a'): True,
#   ('unravel', 'a'): True,
#   ('now', 'i'): True,
#   ('since', 'i'): True,
#   ('get', 'into'): True,
#   ('into', 'an'): True,
#   ('they', 'get'): True,
#   ('who', 'they'): True,
#   ('the', 'movie'): True,
#   ('and', 'has'): True,
#   ('and', 'then'): True,
#   ('this', 'film'): True,
#   ("'", 've'): True,
#   ('attempt', 'to'): True,
#   ('bit', 'of'): True,
#   ('continues', 'to'): True,
#   ('explanation', 'to'): True,
#   ('kind', 'of'): True,
#   ('looooot', 'of'): True,
#   ('might', "'"): True,
#   ('need', 'to'): True,
#   ('nightmare', 'of'): True,
#   ('of', 'chase'): True,
#   ('of', 'echoes'): True,
#   ('of', 'elm'): True,
#   ('of', 'fed'): True,
#   ('of', 'making'): True,
#   ('of', 'understanding'): True,
#   ('of', 'weird'): True,
#   ('packaged', 'to'): True,
#   ('password', 'to'): True,
#   ('seem', 'to'): True,
#   ('seemed', 'to'): True,
#   ('seems', 'to'): True,
#   ('start', 'to'): True,
#   ('stir', 'of'): True,
#   ('to', 'be'): True,
#   ('to', 'break'): True,
#   ('to', 'enter'): True,
#   ('to', 'unravel'): True,
#   ('to', 'want'): True,
#   ('to', 'write'): True,
#   ('tons', 'of'): True,
#   ('trying', 'to'): True,
#   ('types', 'of'): True,
#   ('want', 'to'): True,
#   ('ways', 'of'): True,
#   ('where', "'"): True,
#   ('did', 'in'): True,
#   ('world', 'in'): True,
#   ('for', 'most'): True,
#   ('from', 'its'): True,
#   ('what', "'"): True,
#   ('they', 'are'): True,
#   ('(', 'lost'): True,
#   ('crow', '('): True,
#   ('highway', '('): True,
#   ('memento', '('): True,
#   ('memento', ')'): True,
#   ('others', '('): True,
#   ('s', 'biggest'): True,
#   ('s', 'going'): True,
#   ('s', 'simply'): True,
#   ('?', 'not'): True,
#   ('so', 'all'): True,
#   ('t', 'mind'): True},
#  'positive')
